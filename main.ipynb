# %%
# This script:
#   - Checks if CUDA-enabled GPUs are available.
#   - Configures Spark for 6 cores and ~10GB total (5g each for driver and executor).
#   - If GPUs are available and your environment supports RAPIDS, extra GPU configurations are applied.
#   - Ingests and filters a massive CSV file using a defined schema.
#   - Performs anomaly filtering (keeps rows where soil_moisture is within ±3 standard deviations).
#   - Sorts data by multiple columns and applies further filtering.
#   - Computes descriptive statistics (mean, median, stddev, Q1, Q3) for carbon_percent and nitrogen_percent.
#   - Interpolates missing carbon_percent values (if null, sets value to soil_moisture * 0.05).
#   - Builds and tests a Linear Regression model (using Spark ML) to predict carbon_percent from soil_moisture and temperature.
#   - Generates a bar chart (in a separate thread) of the nutrient statistics.
#   - Reports total runtime.
  
# Note: To truly leverage GPUs make sure your Spark cluster is configured for GPU acceleration (e.g., with RAPIDS Accelerator) and that the necessary drivers and discovery scripts are available.

import os
import time
import subprocess
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from threading import Thread

from pyspark.sql import SparkSession
from pyspark.sql.functions import col, mean, stddev, percentile_approx, when
from pyspark.sql.types import StructType, StructField, IntegerType, FloatType
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression

# %%
# Function to check for CUDA-enabled GPUs.
def has_cuda():
    try:
        import torch
        return torch.cuda.is_available()
    except ImportError:
        try:
            result = subprocess.run(["nvidia-smi"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
            return result.returncode == 0
        except Exception:
            return False

# %%
# Determine compute mode.
use_gpu = has_cuda()
if use_gpu:
    print("CUDA cores detected. Configuring Spark for GPU acceleration.")
else:
    print("No CUDA cores detected. Running on CPU.")
# Out:
# CUDA cores detected. Configuring Spark for GPU acceleration.

# %%
# Start timing
start_time = time.time()

# 1. Define schema for the CSV
schema = StructType([
    StructField("timestamp", IntegerType(), True),
    StructField("soil_moisture", FloatType(), True),
    StructField("soil_water_content", FloatType(), True),
    StructField("carbon_percent", FloatType(), True),
    StructField("nitrogen_percent", FloatType(), True),
    StructField("atmospheric_humidity", FloatType(), True),
    StructField("temperature", FloatType(), True),
    StructField("pH", FloatType(), True)
])

rapids_jar_path = "/mnt/d/TechNex25/1BRC/Round_2/rapids-4-spark_2.12-24.04.1.jar"
temp_dir_path = "/mnt/d/spark_temp/"

spark = SparkSession.builder \
    .appName("1BRC_Round2") \
    .master("local[6]") \
    .config("spark.driver.host", "127.0.0.1") \
    .config("spark.driver.bindAddress", "127.0.0.1") \
    .config("spark.executor.bindAddress", "127.0.0.1") \
    .config("spark.driver.memory", "5g") \
    .config("spark.executor.memory", "5g") \
    .config("spark.local.dir", temp_dir_path) \
    .config("spark.jars", rapids_jar_path) \
    .config("spark.plugins", "com.nvidia.spark.SQLPlugin") \
    .config("spark.rapids.sql.enabled", "true") \
    .config("spark.sql.shuffle.partitions", "20") \
    .config("spark.default.parallelism", "12") \
    .config("spark.sql.adaptive.enabled", "true") \
    .getOrCreate()

print("Spark session successfully synchronized on localhost with GPU acceleration!")
# Out:
# 26/06/10 18:51:30 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).
# 26/06/10 18:51:30 WARN RapidsPluginUtils: RAPIDS Accelerator is enabled, to disable GPU support set `spark.rapids.sql.enabled` to false.
# 26/06/10 18:51:30 WARN RapidsPluginUtils: spark.rapids.sql.explain is set to `NOT_ON_GPU`. Set it to 'NONE' to suppress the diagnostics logging about the query placement on the GPU.
# 26/06/10 18:51:41 ERROR Inbox: Ignoring error
# java.lang.NullPointerException: Cannot invoke "org.apache.spark.storage.BlockManagerId.executorId()" because "idWithoutTopologyInfo" is null
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:677)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
# 26/06/10 18:51:41 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:572)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:358)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
# Caused by: java.lang.NullPointerException: Cannot invoke "org.apache.spark.storage.BlockManagerId.executorId()" because "idWithoutTopologyInfo" is null
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:677)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Spark session successfully synchronized on localhost with GPU acceleration!

# %%
# Task 1: Data Ingestion & Preparation.
print("Task 1: Data Ingestion & Preparation")
file_path = "combined.csv"  # Update with your CSV file location.
try:
    df = spark.read.schema(schema).csv(file_path, header=True) \
            .filter(
                (col("soil_moisture").between(0, 100)) &
                (col("soil_water_content").between(0, 100)) &
                (col("carbon_percent").between(0, 10)) &
                (col("nitrogen_percent").between(0, 5)) &
                (col("atmospheric_humidity").between(0, 100)) &
                (col("temperature").between(0, 40)) &
                (col("pH").between(4, 9))
            )
    print("Data loaded with initial filtering.")
    sample_df = df.sample(fraction=0.0001, seed=42)
    sample_count = sample_df.count()
    estimated_rows = int(sample_count / 0.0001)
    print(f"Estimated total rows: ~{estimated_rows}")
except Exception as e:
    print(f"Error loading CSV: {e}")
    spark.stop()
    exit(1)
# Out:
# Task 1: Data Ingestion & Preparation
# Data loaded with initial filtering.
# [Stage 2:>                                                          (0 + 1) / 1]
# Estimated total rows: ~798410000

# %%
# Task 2: Cleaning – Anomaly Filtering Only.
print("Task 2: Cleaning Data (Anomaly Filtering Only)")
stats_row = df.sample(fraction=0.001, seed=42) \
              .select(mean("soil_moisture").alias("mean_moisture"),
                      stddev("soil_moisture").alias("stddev_moisture")
              ).collect()[0]
mean_moisture = stats_row["mean_moisture"]
stddev_moisture = stats_row["stddev_moisture"]
df_clean = df.filter(((col("soil_moisture") - mean_moisture) / stddev_moisture).between(-3, 3))
print("Sample of anomaly-filtered data:")
df_clean.show(5)
# Out:
# Task 2: Cleaning Data (Anomaly Filtering Only)
# Sample of anomaly-filtered data:
# 26/06/10 18:28:06 WARN GpuOverrides:
# !Exec <CollectLimitExec> cannot run on GPU because the Exec CollectLimitExec has been disabled, and is disabled by default because Collect Limit replacement can be slower on the GPU, if huge number of rows in a batch it could help by limiting the number of rows transferred from GPU to CPU. Set spark.rapids.sql.exec.CollectLimitExec to true if you wish to enable it
#   @Partitioning <SinglePartition$> could run on GPU
#   !Exec <ProjectExec> cannot run on GPU because not all expressions can be replaced
#     @Expression <Alias> toprettystring(timestamp#0, Some(Asia/Kolkata)) AS toprettystring(timestamp)#566 could run on GPU
#       !Expression <ToPrettyString> toprettystring(timestamp#0, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> timestamp#0 could run on GPU
#     @Expression <Alias> toprettystring(soil_moisture#1, Some(Asia/Kolkata)) AS toprettystring(soil_moisture)#567 could run on GPU
#       !Expression <ToPrettyString> toprettystring(soil_moisture#1, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> soil_moisture#1 could run on GPU
#     @Expression <Alias> toprettystring(soil_water_content#2, Some(Asia/Kolkata)) AS toprettystring(soil_water_content)#568 could run on GPU
#       !Expression <ToPrettyString> toprettystring(soil_water_content#2, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> soil_water_content#2 could run on GPU
#     @Expression <Alias> toprettystring(carbon_percent#3, Some(Asia/Kolkata)) AS toprettystring(carbon_percent)#569 could run on GPU
#       !Expression <ToPrettyString> toprettystring(carbon_percent#3, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> carbon_percent#3 could run on GPU
#     @Expression <Alias> toprettystring(nitrogen_percent#4, Some(Asia/Kolkata)) AS toprettystring(nitrogen_percent)#570 could run on GPU
#       !Expression <ToPrettyString> toprettystring(nitrogen_percent#4, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> nitrogen_percent#4 could run on GPU
#     @Expression <Alias> toprettystring(atmospheric_humidity#5, Some(Asia/Kolkata)) AS toprettystring(atmospheric_humidity)#571 could run on GPU
#       !Expression <ToPrettyString> toprettystring(atmospheric_humidity#5, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> atmospheric_humidity#5 could run on GPU
#     @Expression <Alias> toprettystring(temperature#6, Some(Asia/Kolkata)) AS toprettystring(temperature)#572 could run on GPU
#       !Expression <ToPrettyString> toprettystring(temperature#6, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> temperature#6 could run on GPU
#     @Expression <Alias> toprettystring(pH#7, Some(Asia/Kolkata)) AS toprettystring(pH)#573 could run on GPU
#       !Expression <ToPrettyString> toprettystring(pH#7, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> pH#7 could run on GPU
# +---------+-------------+------------------+--------------+----------------+--------------------+-----------+----+
# |timestamp|soil_moisture|soil_water_content|carbon_percent|nitrogen_percent|atmospheric_humidity|temperature|  pH|
# +---------+-------------+------------------+--------------+----------------+--------------------+-----------+----+
# |        2|          1.5|             59.92|          8.34|            3.59|               53.55|       9.82|8.01|
# |        3|        59.39|              82.4|          2.05|            2.71|               67.54|      39.78|5.03|
# |        5|        54.58|             77.19|          5.34|            3.32|               30.31|       32.0|8.44|
# |        6|        66.24|             12.15|          1.49|            2.69|                3.43|       1.22|8.07|
# |        7|        81.44|             60.34|          6.56|            0.62|               10.97|      15.28|5.75|
# +---------+-------------+------------------+--------------+----------------+--------------------+-----------+----+
# only showing top 5 rows

# %%
# Task 3: Multi-Column Sorting & Filtering.
print("Task 3: Multi-Column Sorting & Filtering")
sorted_sample = df_clean.sample(fraction=0.0001, seed=42) \
                        .orderBy("timestamp", "soil_moisture", "temperature")
print("Sorted sample:")
sorted_sample.show(5)
filtered_df = df_clean.filter((col("soil_moisture") > 80) & (col("pH") < 5))
print("Filtered sample:")
filtered_df.show(5)
# Out:
# Task 3: Multi-Column Sorting & Filtering
# Sorted sample:
# 26/06/10 18:28:12 WARN GpuOverrides:
# !Exec <TakeOrderedAndProjectExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <SortOrder> timestamp#0 ASC NULLS FIRST could run on GPU
#     @Expression <AttributeReference> timestamp#0 could run on GPU
#   @Expression <SortOrder> soil_moisture#1 ASC NULLS FIRST could run on GPU
#     @Expression <AttributeReference> soil_moisture#1 could run on GPU
#   @Expression <SortOrder> temperature#6 ASC NULLS FIRST could run on GPU
#     @Expression <AttributeReference> temperature#6 could run on GPU
#   @Expression <Alias> toprettystring(timestamp#0, Some(Asia/Kolkata)) AS toprettystring(timestamp)#600 could run on GPU
#     !Expression <ToPrettyString> toprettystring(timestamp#0, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#       @Expression <AttributeReference> timestamp#0 could run on GPU
#   @Expression <Alias> toprettystring(soil_moisture#1, Some(Asia/Kolkata)) AS toprettystring(soil_moisture)#601 could run on GPU
#     !Expression <ToPrettyString> toprettystring(soil_moisture#1, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#       @Expression <AttributeReference> soil_moisture#1 could run on GPU
#   @Expression <Alias> toprettystring(soil_water_content#2, Some(Asia/Kolkata)) AS toprettystring(soil_water_content)#602 could run on GPU
#     !Expression <ToPrettyString> toprettystring(soil_water_content#2, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#       @Expression <AttributeReference> soil_water_content#2 could run on GPU
#   @Expression <Alias> toprettystring(carbon_percent#3, Some(Asia/Kolkata)) AS toprettystring(carbon_percent)#603 could run on GPU
#     !Expression <ToPrettyString> toprettystring(carbon_percent#3, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#       @Expression <AttributeReference> carbon_percent#3 could run on GPU
#   @Expression <Alias> toprettystring(nitrogen_percent#4, Some(Asia/Kolkata)) AS toprettystring(nitrogen_percent)#604 could run on GPU
#     !Expression <ToPrettyString> toprettystring(nitrogen_percent#4, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#       @Expression <AttributeReference> nitrogen_percent#4 could run on GPU
#   @Expression <Alias> toprettystring(atmospheric_humidity#5, Some(Asia/Kolkata)) AS toprettystring(atmospheric_humidity)#605 could run on GPU
#     !Expression <ToPrettyString> toprettystring(atmospheric_humidity#5, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#       @Expression <AttributeReference> atmospheric_humidity#5 could run on GPU
#   @Expression <Alias> toprettystring(temperature#6, Some(Asia/Kolkata)) AS toprettystring(temperature)#606 could run on GPU
#     !Expression <ToPrettyString> toprettystring(temperature#6, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#       @Expression <AttributeReference> temperature#6 could run on GPU
#   @Expression <Alias> toprettystring(pH#7, Some(Asia/Kolkata)) AS toprettystring(pH)#607 could run on GPU
#     !Expression <ToPrettyString> toprettystring(pH#7, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#       @Expression <AttributeReference> pH#7 could run on GPU
# +---------+-------------+------------------+--------------+----------------+--------------------+-----------+----+
# |timestamp|soil_moisture|soil_water_content|carbon_percent|nitrogen_percent|atmospheric_humidity|temperature|  pH|
# +---------+-------------+------------------+--------------+----------------+--------------------+-----------+----+
# |    61166|        66.19|              26.1|          7.78|            0.41|               90.57|      37.13|4.57|
# |    68508|        38.12|              27.2|          3.44|            3.71|               57.62|       6.94|7.44|
# |    74499|        53.46|              7.67|          3.25|            0.69|               76.61|      38.44| 4.7|
# |    75698|        29.86|              57.8|          6.87|            2.67|               47.53|      37.49|8.18|
# |    82680|        44.08|             75.92|          9.57|            1.43|               91.44|      24.54| 7.9|
# +---------+-------------+------------------+--------------+----------------+--------------------+-----------+----+
# only showing top 5 rows
#
# Filtered sample:
# 26/06/10 18:31:45 WARN GpuOverrides:
# !Exec <CollectLimitExec> cannot run on GPU because the Exec CollectLimitExec has been disabled, and is disabled by default because Collect Limit replacement can be slower on the GPU, if huge number of rows in a batch it could help by limiting the number of rows transferred from GPU to CPU. Set spark.rapids.sql.exec.CollectLimitExec to true if you wish to enable it
#   @Partitioning <SinglePartition$> could run on GPU
#   !Exec <ProjectExec> cannot run on GPU because not all expressions can be replaced
#     @Expression <Alias> toprettystring(timestamp#0, Some(Asia/Kolkata)) AS toprettystring(timestamp)#634 could run on GPU
#       !Expression <ToPrettyString> toprettystring(timestamp#0, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> timestamp#0 could run on GPU
#     @Expression <Alias> toprettystring(soil_moisture#1, Some(Asia/Kolkata)) AS toprettystring(soil_moisture)#635 could run on GPU
#       !Expression <ToPrettyString> toprettystring(soil_moisture#1, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> soil_moisture#1 could run on GPU
#     @Expression <Alias> toprettystring(soil_water_content#2, Some(Asia/Kolkata)) AS toprettystring(soil_water_content)#636 could run on GPU
#       !Expression <ToPrettyString> toprettystring(soil_water_content#2, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> soil_water_content#2 could run on GPU
#     @Expression <Alias> toprettystring(carbon_percent#3, Some(Asia/Kolkata)) AS toprettystring(carbon_percent)#637 could run on GPU
#       !Expression <ToPrettyString> toprettystring(carbon_percent#3, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> carbon_percent#3 could run on GPU
#     @Expression <Alias> toprettystring(nitrogen_percent#4, Some(Asia/Kolkata)) AS toprettystring(nitrogen_percent)#638 could run on GPU
#       !Expression <ToPrettyString> toprettystring(nitrogen_percent#4, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> nitrogen_percent#4 could run on GPU
#     @Expression <Alias> toprettystring(atmospheric_humidity#5, Some(Asia/Kolkata)) AS toprettystring(atmospheric_humidity)#639 could run on GPU
#       !Expression <ToPrettyString> toprettystring(atmospheric_humidity#5, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> atmospheric_humidity#5 could run on GPU
#     @Expression <Alias> toprettystring(temperature#6, Some(Asia/Kolkata)) AS toprettystring(temperature)#640 could run on GPU
#       !Expression <ToPrettyString> toprettystring(temperature#6, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> temperature#6 could run on GPU
#     @Expression <Alias> toprettystring(pH#7, Some(Asia/Kolkata)) AS toprettystring(pH)#641 could run on GPU
#       !Expression <ToPrettyString> toprettystring(pH#7, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> pH#7 could run on GPU
#
# [Stage 8:>                                                          (0 + 1) / 1]
# +---------+-------------+------------------+--------------+----------------+--------------------+-----------+----+
# |timestamp|soil_moisture|soil_water_content|carbon_percent|nitrogen_percent|atmospheric_humidity|temperature|  pH|
# +---------+-------------+------------------+--------------+----------------+--------------------+-----------+----+
# |       58|        89.17|              9.45|          0.65|            3.69|               47.08|       36.3|4.85|
# |       81|         82.7|             57.07|          4.34|            4.44|               10.99|       3.85|4.58|
# |      124|         82.3|             16.52|          6.78|            0.67|               78.89|      22.29|4.53|
# |      162|        88.89|               7.8|          8.01|            2.59|               79.28|      20.31|4.86|
# |      170|        82.53|             55.56|          7.48|            1.82|               57.71|      31.78|4.85|
# +---------+-------------+------------------+--------------+----------------+--------------------+-----------+----+
# only showing top 5 rows

# %%
# Task 4: Statistical Analysis.
print("Task 4: Statistical Analysis")
stats = df_clean.select(
    mean("carbon_percent").alias("carbon_mean"),
    percentile_approx("carbon_percent", 0.5, 1000).alias("carbon_median"),
    stddev("carbon_percent").alias("carbon_stddev"),
    percentile_approx("carbon_percent", [0.25, 0.75], 1000).alias("carbon_quartiles"),
    mean("nitrogen_percent").alias("nitrogen_mean"),
    percentile_approx("nitrogen_percent", 0.5, 1000).alias("nitrogen_median"),
    stddev("nitrogen_percent").alias("nitrogen_stddev"),
    percentile_approx("nitrogen_percent", [0.25, 0.75], 1000).alias("nitrogen_quartiles")
).collect()[0]
print(f"Carbon Percent -> Mean: {stats['carbon_mean']:.2f}, Median: {stats['carbon_median']:.2f}, StdDev: {stats['carbon_stddev']:.2f}, " +
      f"Q1: {stats['carbon_quartiles'][0]:.2f}, Q3: {stats['carbon_quartiles'][1]:.2f}")
print(f"Nitrogen Percent -> Mean: {stats['nitrogen_mean']:.2f}, Median: {stats['nitrogen_median']:.2f}, StdDev: {stats['nitrogen_stddev']:.2f}, " +
      f"Q1: {stats['nitrogen_quartiles'][0]:.2f}, Q3: {stats['nitrogen_quartiles'][1]:.2f}")
# Out:
# Task 4: Statistical Analysis
# [Stage 11:>                                                         (0 + 1) / 1]
# Carbon Percent -> Mean: 5.00, Median: 5.00, StdDev: 2.89, Q1: 2.50, Q3: 7.50
# Nitrogen Percent -> Mean: 2.50, Median: 2.50, StdDev: 1.44, Q1: 1.25, Q3: 3.75

# %%
# Task 5: Interpolation & Prediction.
print("Task 5: Interpolation & Prediction")
df_interp = df_clean.withColumn("carbon_percent_interp",
                    when(col("carbon_percent").isNull(), col("soil_moisture") * 0.05)
                    .otherwise(col("carbon_percent"))
                )
sample_pred = df_interp.sample(fraction=0.001, seed=42)
assembler = VectorAssembler(inputCols=["soil_moisture", "temperature"], outputCol="features")
df_vector = assembler.transform(sample_pred)
train_df, test_df = df_vector.randomSplit([0.8, 0.2], seed=42)
lr = LinearRegression(featuresCol="features", labelCol="carbon_percent_interp")
lr_model = lr.fit(train_df)
predictions = lr_model.transform(test_df)
print("Prediction sample:")
predictions.select("timestamp", "soil_moisture", "temperature", "carbon_percent_interp", "prediction").show(5)
# Out:
# Task 5: Interpolation & Prediction
# 26/06/10 18:35:33 WARN GpuOverrides:
# ! <DeserializeToObjectExec> cannot run on GPU because not all expressions can be replaced; GPU does not currently support the operator class org.apache.spark.sql.execution.DeserializeToObjectExec
#   ! <CreateExternalRow> createexternalrow(staticinvoke(class java.lang.Integer, ObjectType(class java.lang.Integer), valueOf, timestamp#0, true, false, true), staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, soil_moisture#1, true, false, true), staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, soil_water_content#2, true, false, true), staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, carbon_percent#3, true, false, true), staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, nitrogen_percent#4, true, false, true), staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, atmospheric_humidity#5, true, false, true), staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, temperature#6, true, false, true), staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, pH#7, true, false, true), staticinvoke(class java.lang.Double, ObjectType(class java.lang.Double), valueOf, carbon_percent_interp#6771, true, false, true), newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize, StructField(timestamp,IntegerType,true), StructField(soil_moisture,FloatType,true), StructField(soil_water_content,FloatType,true), StructField(carbon_percent,FloatType,true), StructField(nitrogen_percent,FloatType,true), StructField(atmospheric_humidity,FloatType,true), StructField(temperature,FloatType,true), StructField(pH,FloatType,true), StructField(carbon_percent_interp,DoubleType,true), StructField(features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#     ! <StaticInvoke> staticinvoke(class java.lang.Integer, ObjectType(class java.lang.Integer), valueOf, timestamp#0, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> timestamp#0 could run on GPU
#     ! <StaticInvoke> staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, soil_moisture#1, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> soil_moisture#1 could run on GPU
#     ! <StaticInvoke> staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, soil_water_content#2, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> soil_water_content#2 could run on GPU
#     ! <StaticInvoke> staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, carbon_percent#3, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> carbon_percent#3 could run on GPU
#     ! <StaticInvoke> staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, nitrogen_percent#4, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> nitrogen_percent#4 could run on GPU
#     ! <StaticInvoke> staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, atmospheric_humidity#5, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> atmospheric_humidity#5 could run on GPU
#     ! <StaticInvoke> staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, temperature#6, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> temperature#6 could run on GPU
#     ! <StaticInvoke> staticinvoke(class java.lang.Float, ObjectType(class java.lang.Float), valueOf, pH#7, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> pH#7 could run on GPU
#     ! <StaticInvoke> staticinvoke(class java.lang.Double, ObjectType(class java.lang.Double), valueOf, carbon_percent_interp#6771, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#     ! <Invoke> newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#       ! <NewInstance> newInstance(class org.apache.spark.ml.linalg.VectorUDT) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.NewInstance
#       !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#   !Expression <AttributeReference> obj#6807 cannot run on GPU because expression AttributeReference obj#6807 produces an unsupported type ObjectType(interface org.apache.spark.sql.Row)
#   !Exec <SampleExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#     !Exec <SortExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#       @Expression <SortOrder> timestamp#0 ASC NULLS FIRST could run on GPU
#         @Expression <AttributeReference> timestamp#0 could run on GPU
#       @Expression <SortOrder> soil_moisture#1 ASC NULLS FIRST could run on GPU
#         @Expression <AttributeReference> soil_moisture#1 could run on GPU
#       @Expression <SortOrder> soil_water_content#2 ASC NULLS FIRST could run on GPU
#         @Expression <AttributeReference> soil_water_content#2 could run on GPU
#       @Expression <SortOrder> carbon_percent#3 ASC NULLS FIRST could run on GPU
#         @Expression <AttributeReference> carbon_percent#3 could run on GPU
#       @Expression <SortOrder> nitrogen_percent#4 ASC NULLS FIRST could run on GPU
#         @Expression <AttributeReference> nitrogen_percent#4 could run on GPU
#       @Expression <SortOrder> atmospheric_humidity#5 ASC NULLS FIRST could run on GPU
#         @Expression <AttributeReference> atmospheric_humidity#5 could run on GPU
#       @Expression <SortOrder> temperature#6 ASC NULLS FIRST could run on GPU
#         @Expression <AttributeReference> temperature#6 could run on GPU
#       @Expression <SortOrder> pH#7 ASC NULLS FIRST could run on GPU
#         @Expression <AttributeReference> pH#7 could run on GPU
#       @Expression <SortOrder> carbon_percent_interp#6771 ASC NULLS FIRST could run on GPU
#         @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#       !Expression <SortOrder> features#6784 ASC NULLS FIRST cannot run on GPU because input expression AttributeReference features#6784 (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression SortOrder features#6784 ASC NULLS FIRST produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#       !Exec <ProjectExec> cannot run on GPU because not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#         @Expression <AttributeReference> timestamp#0 could run on GPU
#         @Expression <AttributeReference> soil_moisture#1 could run on GPU
#         @Expression <AttributeReference> soil_water_content#2 could run on GPU
#         @Expression <AttributeReference> carbon_percent#3 could run on GPU
#         @Expression <AttributeReference> nitrogen_percent#4 could run on GPU
#         @Expression <AttributeReference> atmospheric_humidity#5 could run on GPU
#         @Expression <AttributeReference> temperature#6 could run on GPU
#         @Expression <AttributeReference> pH#7 could run on GPU
#         @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#         !Expression <Alias> UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) AS features#6784 cannot run on GPU because expression Alias UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) AS features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#           !Expression <ScalaUDF> UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) cannot run on GPU because expression ScalaUDF UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; neither UDF implemented by class org.apache.spark.ml.feature.VectorAssembler$$Lambda/0x000070d7f92dd550 provides a GPU implementation, nor the conf `spark.rapids.sql.rowBasedUDF.enabled` is enabled
#             @Expression <CreateNamedStruct> struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double)) could run on GPU
#               @Expression <Literal> soil_moisture_double_VectorAssembler_ccdf63b443b9 could run on GPU
#               @Expression <Cast> cast(soil_moisture#1 as double) could run on GPU
#                 @Expression <AttributeReference> soil_moisture#1 could run on GPU
#               @Expression <Literal> temperature_double_VectorAssembler_ccdf63b443b9 could run on GPU
#               @Expression <Cast> cast(temperature#6 as double) could run on GPU
#                 @Expression <AttributeReference> temperature#6 could run on GPU
#
# 26/06/10 18:35:33 WARN GpuOverrides:
# ! <DeserializeToObjectExec> cannot run on GPU because not all expressions can be replaced; GPU does not currently support the operator class org.apache.spark.sql.execution.DeserializeToObjectExec
#   ! <CreateExternalRow> createexternalrow(staticinvoke(class java.lang.Double, ObjectType(class java.lang.Double), valueOf, CASE WHEN ((CAST(carbon_percent_interp AS DOUBLE) IS NULL) OR isnan(CAST(carbon_percent_interp AS DOUBLE))) THEN raise_error(Labels MUST NOT be Null or NaN) WHEN ((CAST(carbon_percent_interp AS DOUBLE) = -Infinity) OR (CAST(carbon_percent_interp AS DOUBLE) = Infinity)) THEN raise_error(concat(Labels MUST NOT be Infinity, but got , CAST(carbon_percent_interp AS DOUBLE))) ELSE CAST(carbon_percent_interp AS DOUBLE) END#6812, true, false, true), staticinvoke(class java.lang.Double, ObjectType(class java.lang.Double), valueOf, 1.0#6811, true, false, true), newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize, StructField(CASE WHEN ((CAST(carbon_percent_interp AS DOUBLE) IS NULL) OR isnan(CAST(carbon_percent_interp AS DOUBLE))) THEN raise_error(Labels MUST NOT be Null or NaN) WHEN ((CAST(carbon_percent_interp AS DOUBLE) = -Infinity) OR (CAST(carbon_percent_interp AS DOUBLE) = Infinity)) THEN raise_error(concat(Labels MUST NOT be Infinity, but got , CAST(carbon_percent_interp AS DOUBLE))) ELSE CAST(carbon_percent_interp AS DOUBLE) END,DoubleType,true), StructField(1.0,DoubleType,false), StructField(CASE WHEN (features IS NULL) THEN raise_error(Vectors MUST NOT be Null) WHEN (NOT UDF(features)) THEN raise_error(concat(Vector values MUST NOT be NaN or Infinity, but got , CAST(features AS STRING))) ELSE features END,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#     ! <StaticInvoke> staticinvoke(class java.lang.Double, ObjectType(class java.lang.Double), valueOf, CASE WHEN ((CAST(carbon_percent_interp AS DOUBLE) IS NULL) OR isnan(CAST(carbon_percent_interp AS DOUBLE))) THEN raise_error(Labels MUST NOT be Null or NaN) WHEN ((CAST(carbon_percent_interp AS DOUBLE) = -Infinity) OR (CAST(carbon_percent_interp AS DOUBLE) = Infinity)) THEN raise_error(concat(Labels MUST NOT be Infinity, but got , CAST(carbon_percent_interp AS DOUBLE))) ELSE CAST(carbon_percent_interp AS DOUBLE) END#6812, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> CASE WHEN ((CAST(carbon_percent_interp AS DOUBLE) IS NULL) OR isnan(CAST(carbon_percent_interp AS DOUBLE))) THEN raise_error(Labels MUST NOT be Null or NaN) WHEN ((CAST(carbon_percent_interp AS DOUBLE) = -Infinity) OR (CAST(carbon_percent_interp AS DOUBLE) = Infinity)) THEN raise_error(concat(Labels MUST NOT be Infinity, but got , CAST(carbon_percent_interp AS DOUBLE))) ELSE CAST(carbon_percent_interp AS DOUBLE) END#6812 could run on GPU
#     ! <StaticInvoke> staticinvoke(class java.lang.Double, ObjectType(class java.lang.Double), valueOf, 1.0#6811, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> 1.0#6811 could run on GPU
#     ! <Invoke> newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#       ! <NewInstance> newInstance(class org.apache.spark.ml.linalg.VectorUDT) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.NewInstance
#       !Expression <AttributeReference> CASE WHEN (features IS NULL) THEN raise_error(Vectors MUST NOT be Null) WHEN (NOT UDF(features)) THEN raise_error(concat(Vector values MUST NOT be NaN or Infinity, but got , CAST(features AS STRING))) ELSE features END#6813 cannot run on GPU because expression AttributeReference CASE WHEN (features IS NULL) THEN raise_error(Vectors MUST NOT be Null) WHEN (NOT UDF(features)) THEN raise_error(concat(Vector values MUST NOT be NaN or Infinity, but got , CAST(features AS STRING))) ELSE features END#6813 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#   !Expression <AttributeReference> obj#6820 cannot run on GPU because expression AttributeReference obj#6820 produces an unsupported type ObjectType(interface org.apache.spark.sql.Row)
#   !Exec <ProjectExec> cannot run on GPU because unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [CASE WHEN (features IS NULL) THEN raise_error(Vectors MUST NOT be Null) WHEN (NOT UDF(features)) THEN raise_error(concat(Vector values MUST NOT be NaN or Infinity, but got , CAST(features AS STRING))) ELSE features END#6813]; unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; not all expressions can be replaced
#     @Expression <Alias> CASE WHEN (isnull(carbon_percent_interp#6771) OR isnan(carbon_percent_interp#6771)) THEN cast(raise_error(Labels MUST NOT be Null or NaN, NullType) as double) WHEN ((carbon_percent_interp#6771 = -Infinity) OR (carbon_percent_interp#6771 = Infinity)) THEN cast(raise_error(concat(Labels MUST NOT be Infinity, but got , cast(carbon_percent_interp#6771 as string)), NullType) as double) ELSE carbon_percent_interp#6771 END AS CASE WHEN ((CAST(carbon_percent_interp AS DOUBLE) IS NULL) OR isnan(CAST(carbon_percent_interp AS DOUBLE))) THEN raise_error(Labels MUST NOT be Null or NaN) WHEN ((CAST(carbon_percent_interp AS DOUBLE) = -Infinity) OR (CAST(carbon_percent_interp AS DOUBLE) = Infinity)) THEN raise_error(concat(Labels MUST NOT be Infinity, but got , CAST(carbon_percent_interp AS DOUBLE))) ELSE CAST(carbon_percent_interp AS DOUBLE) END#6812 could run on GPU
#       @Expression <CaseWhen> CASE WHEN (isnull(carbon_percent_interp#6771) OR isnan(carbon_percent_interp#6771)) THEN cast(raise_error(Labels MUST NOT be Null or NaN, NullType) as double) WHEN ((carbon_percent_interp#6771 = -Infinity) OR (carbon_percent_interp#6771 = Infinity)) THEN cast(raise_error(concat(Labels MUST NOT be Infinity, but got , cast(carbon_percent_interp#6771 as string)), NullType) as double) ELSE carbon_percent_interp#6771 END could run on GPU
#         @Expression <Or> (isnull(carbon_percent_interp#6771) OR isnan(carbon_percent_interp#6771)) could run on GPU
#           @Expression <IsNull> isnull(carbon_percent_interp#6771) could run on GPU
#             @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#           @Expression <IsNaN> isnan(carbon_percent_interp#6771) could run on GPU
#             @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#         @Expression <Cast> cast(raise_error(Labels MUST NOT be Null or NaN, NullType) as double) could run on GPU
#           @Expression <RaiseError> raise_error(Labels MUST NOT be Null or NaN, NullType) could run on GPU
#             @Expression <Literal> Labels MUST NOT be Null or NaN could run on GPU
#         @Expression <Or> ((carbon_percent_interp#6771 = -Infinity) OR (carbon_percent_interp#6771 = Infinity)) could run on GPU
#           @Expression <EqualTo> (carbon_percent_interp#6771 = -Infinity) could run on GPU
#             @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#             @Expression <Literal> -Infinity could run on GPU
#           @Expression <EqualTo> (carbon_percent_interp#6771 = Infinity) could run on GPU
#             @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#             @Expression <Literal> Infinity could run on GPU
#         @Expression <Cast> cast(raise_error(concat(Labels MUST NOT be Infinity, but got , cast(carbon_percent_interp#6771 as string)), NullType) as double) could run on GPU
#           @Expression <RaiseError> raise_error(concat(Labels MUST NOT be Infinity, but got , cast(carbon_percent_interp#6771 as string)), NullType) could run on GPU
#             @Expression <Concat> concat(Labels MUST NOT be Infinity, but got , cast(carbon_percent_interp#6771 as string)) could run on GPU
#               @Expression <Literal> Labels MUST NOT be Infinity, but got  could run on GPU
#               @Expression <Cast> cast(carbon_percent_interp#6771 as string) could run on GPU
#                 @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#         @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#     @Expression <Alias> 1.0 AS 1.0#6811 could run on GPU
#       @Expression <Literal> 1.0 could run on GPU
#     !Expression <Alias> CASE WHEN isnull(features#6784) THEN cast(raise_error(Vectors MUST NOT be Null, NullType) as vector) WHEN NOT UDF(features#6784) THEN cast(raise_error(concat(Vector values MUST NOT be NaN or Infinity, but got , cast(features#6784 as string)), NullType) as vector) ELSE features#6784 END AS CASE WHEN (features IS NULL) THEN raise_error(Vectors MUST NOT be Null) WHEN (NOT UDF(features)) THEN raise_error(concat(Vector values MUST NOT be NaN or Infinity, but got , CAST(features AS STRING))) ELSE features END#6813 cannot run on GPU because expression Alias CASE WHEN isnull(features#6784) THEN cast(raise_error(Vectors MUST NOT be Null, NullType) as vector) WHEN NOT UDF(features#6784) THEN cast(raise_error(concat(Vector values MUST NOT be NaN or Infinity, but got , cast(features#6784 as string)), NullType) as vector) ELSE features#6784 END AS CASE WHEN (features IS NULL) THEN raise_error(Vectors MUST NOT be Null) WHEN (NOT UDF(features)) THEN raise_error(concat(Vector values MUST NOT be NaN or Infinity, but got , CAST(features AS STRING))) ELSE features END#6813 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression CaseWhen CASE WHEN isnull(features#6784) THEN cast(raise_error(Vectors MUST NOT be Null, NullType) as vector) WHEN NOT UDF(features#6784) THEN cast(raise_error(concat(Vector values MUST NOT be NaN or Infinity, but got , cast(features#6784 as string)), NullType) as vector) ELSE features#6784 END (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#       !Expression <CaseWhen> CASE WHEN isnull(features#6784) THEN cast(raise_error(Vectors MUST NOT be Null, NullType) as vector) WHEN NOT UDF(features#6784) THEN cast(raise_error(concat(Vector values MUST NOT be NaN or Infinity, but got , cast(features#6784 as string)), NullType) as vector) ELSE features#6784 END cannot run on GPU because else expression AttributeReference features#6784 (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression Cast cast(raise_error(concat(Vector values MUST NOT be NaN or Infinity, but got , cast(features#6784 as string)), NullType) as vector) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression Cast cast(raise_error(Vectors MUST NOT be Null, NullType) as vector) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#         !Expression <IsNull> isnull(features#6784) cannot run on GPU because input expression AttributeReference features#6784 (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#           !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         !Expression <Cast> cast(raise_error(Vectors MUST NOT be Null, NullType) as vector) cannot run on GPU because Cast from NullType to org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported
#           @Expression <RaiseError> raise_error(Vectors MUST NOT be Null, NullType) could run on GPU
#             @Expression <Literal> Vectors MUST NOT be Null could run on GPU
#         @Expression <Not> NOT UDF(features#6784) could run on GPU
#           !Expression <ScalaUDF> UDF(features#6784) cannot run on GPU because neither UDF implemented by class org.apache.spark.ml.util.DatasetUtils$$$Lambda/0x000070d7f932a3d8 provides a GPU implementation, nor the conf `spark.rapids.sql.rowBasedUDF.enabled` is enabled; param expression AttributeReference features#6784 (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#             !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         !Expression <Cast> cast(raise_error(concat(Vector values MUST NOT be NaN or Infinity, but got , cast(features#6784 as string)), NullType) as vector) cannot run on GPU because Cast from NullType to org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported
#           @Expression <RaiseError> raise_error(concat(Vector values MUST NOT be NaN or Infinity, but got , cast(features#6784 as string)), NullType) could run on GPU
#             @Expression <Concat> concat(Vector values MUST NOT be NaN or Infinity, but got , cast(features#6784 as string)) could run on GPU
#               @Expression <Literal> Vector values MUST NOT be NaN or Infinity, but got  could run on GPU
#               !Expression <Cast> cast(features#6784 as string) cannot run on GPU because Cast from org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 to StringType is not supported
#                 !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#     !Exec <SampleExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#       !Exec <ProjectExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#         @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#         !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         !Exec <SortExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#           @Expression <SortOrder> timestamp#0 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> timestamp#0 could run on GPU
#           @Expression <SortOrder> soil_moisture#1 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> soil_moisture#1 could run on GPU
#           @Expression <SortOrder> soil_water_content#2 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> soil_water_content#2 could run on GPU
#           @Expression <SortOrder> carbon_percent#3 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> carbon_percent#3 could run on GPU
#           @Expression <SortOrder> nitrogen_percent#4 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> nitrogen_percent#4 could run on GPU
#           @Expression <SortOrder> atmospheric_humidity#5 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> atmospheric_humidity#5 could run on GPU
#           @Expression <SortOrder> temperature#6 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> temperature#6 could run on GPU
#           @Expression <SortOrder> pH#7 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> pH#7 could run on GPU
#           @Expression <SortOrder> carbon_percent_interp#6771 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#           !Expression <SortOrder> features#6784 ASC NULLS FIRST cannot run on GPU because input expression AttributeReference features#6784 (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression SortOrder features#6784 ASC NULLS FIRST produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#             !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#           !Exec <ProjectExec> cannot run on GPU because not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#             @Expression <AttributeReference> timestamp#0 could run on GPU
#             @Expression <AttributeReference> soil_moisture#1 could run on GPU
#             @Expression <AttributeReference> soil_water_content#2 could run on GPU
#             @Expression <AttributeReference> carbon_percent#3 could run on GPU
#             @Expression <AttributeReference> nitrogen_percent#4 could run on GPU
#             @Expression <AttributeReference> atmospheric_humidity#5 could run on GPU
#             @Expression <AttributeReference> temperature#6 could run on GPU
#             @Expression <AttributeReference> pH#7 could run on GPU
#             @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#             !Expression <Alias> UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) AS features#6784 cannot run on GPU because expression Alias UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) AS features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#               !Expression <ScalaUDF> UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) cannot run on GPU because expression ScalaUDF UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; neither UDF implemented by class org.apache.spark.ml.feature.VectorAssembler$$Lambda/0x000070d7f92dd550 provides a GPU implementation, nor the conf `spark.rapids.sql.rowBasedUDF.enabled` is enabled
#                 @Expression <CreateNamedStruct> struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double)) could run on GPU
#                   @Expression <Literal> soil_moisture_double_VectorAssembler_ccdf63b443b9 could run on GPU
#                   @Expression <Cast> cast(soil_moisture#1 as double) could run on GPU
#                     @Expression <AttributeReference> soil_moisture#1 could run on GPU
#                   @Expression <Literal> temperature_double_VectorAssembler_ccdf63b443b9 could run on GPU
#                   @Expression <Cast> cast(temperature#6 as double) could run on GPU
#                     @Expression <AttributeReference> temperature#6 could run on GPU
#
# 26/06/10 18:35:33 WARN Instrumentation: [12934eeb] regParam is zero, which might cause numerical instability and overfitting.
# 26/06/10 18:35:37 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.VectorBLAS
# 26/06/10 18:39:08 WARN GpuOverrides:
# ! <DeserializeToObjectExec> cannot run on GPU because not all expressions can be replaced; GPU does not currently support the operator class org.apache.spark.sql.execution.DeserializeToObjectExec
#   ! <CreateExternalRow> createexternalrow(staticinvoke(class java.lang.Double, ObjectType(class java.lang.Double), valueOf, prediction#6824, true, false, true), staticinvoke(class java.lang.Double, ObjectType(class java.lang.Double), valueOf, carbon_percent_interp#6771, true, false, true), staticinvoke(class java.lang.Double, ObjectType(class java.lang.Double), valueOf, 1.0#6837, true, false, true), StructField(prediction,DoubleType,false), StructField(carbon_percent_interp,DoubleType,true), StructField(1.0,DoubleType,false)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#     ! <StaticInvoke> staticinvoke(class java.lang.Double, ObjectType(class java.lang.Double), valueOf, prediction#6824, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> prediction#6824 could run on GPU
#     ! <StaticInvoke> staticinvoke(class java.lang.Double, ObjectType(class java.lang.Double), valueOf, carbon_percent_interp#6771, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#     ! <StaticInvoke> staticinvoke(class java.lang.Double, ObjectType(class java.lang.Double), valueOf, 1.0#6837, true, false, true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.StaticInvoke
#       @Expression <AttributeReference> 1.0#6837 could run on GPU
#   !Expression <AttributeReference> obj#6841 cannot run on GPU because expression AttributeReference obj#6841 produces an unsupported type ObjectType(interface org.apache.spark.sql.Row)
#   !Exec <ProjectExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; not all expressions can be replaced
#     @Expression <Alias> UDF(features#6784) AS prediction#6824 could run on GPU
#       !Expression <ScalaUDF> UDF(features#6784) cannot run on GPU because neither UDF implemented by class org.apache.spark.ml.PredictionModel$$Lambda/0x000070d7f942f9a8 provides a GPU implementation, nor the conf `spark.rapids.sql.rowBasedUDF.enabled` is enabled; param expression AttributeReference features#6784 (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#         !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#     @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#     @Expression <Alias> 1.0 AS 1.0#6837 could run on GPU
#       @Expression <Literal> 1.0 could run on GPU
#     !Exec <SampleExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#       !Exec <ProjectExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#         @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#         !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         !Exec <SortExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#           @Expression <SortOrder> timestamp#0 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> timestamp#0 could run on GPU
#           @Expression <SortOrder> soil_moisture#1 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> soil_moisture#1 could run on GPU
#           @Expression <SortOrder> soil_water_content#2 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> soil_water_content#2 could run on GPU
#           @Expression <SortOrder> carbon_percent#3 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> carbon_percent#3 could run on GPU
#           @Expression <SortOrder> nitrogen_percent#4 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> nitrogen_percent#4 could run on GPU
#           @Expression <SortOrder> atmospheric_humidity#5 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> atmospheric_humidity#5 could run on GPU
#           @Expression <SortOrder> temperature#6 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> temperature#6 could run on GPU
#           @Expression <SortOrder> pH#7 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> pH#7 could run on GPU
#           @Expression <SortOrder> carbon_percent_interp#6771 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#           !Expression <SortOrder> features#6784 ASC NULLS FIRST cannot run on GPU because input expression AttributeReference features#6784 (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression SortOrder features#6784 ASC NULLS FIRST produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#             !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#           !Exec <ProjectExec> cannot run on GPU because not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#             @Expression <AttributeReference> timestamp#0 could run on GPU
#             @Expression <AttributeReference> soil_moisture#1 could run on GPU
#             @Expression <AttributeReference> soil_water_content#2 could run on GPU
#             @Expression <AttributeReference> carbon_percent#3 could run on GPU
#             @Expression <AttributeReference> nitrogen_percent#4 could run on GPU
#             @Expression <AttributeReference> atmospheric_humidity#5 could run on GPU
#             @Expression <AttributeReference> temperature#6 could run on GPU
#             @Expression <AttributeReference> pH#7 could run on GPU
#             @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#             !Expression <Alias> UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) AS features#6784 cannot run on GPU because expression Alias UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) AS features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#               !Expression <ScalaUDF> UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) cannot run on GPU because expression ScalaUDF UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; neither UDF implemented by class org.apache.spark.ml.feature.VectorAssembler$$Lambda/0x000070d7f92dd550 provides a GPU implementation, nor the conf `spark.rapids.sql.rowBasedUDF.enabled` is enabled
#                 @Expression <CreateNamedStruct> struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double)) could run on GPU
#                   @Expression <Literal> soil_moisture_double_VectorAssembler_ccdf63b443b9 could run on GPU
#                   @Expression <Cast> cast(soil_moisture#1 as double) could run on GPU
#                     @Expression <AttributeReference> soil_moisture#1 could run on GPU
#                   @Expression <Literal> temperature_double_VectorAssembler_ccdf63b443b9 could run on GPU
#                   @Expression <Cast> cast(temperature#6 as double) could run on GPU
#                     @Expression <AttributeReference> temperature#6 could run on GPU
# Prediction sample:
# 26/06/10 18:42:51 WARN GpuOverrides:
# !Exec <CollectLimitExec> cannot run on GPU because the Exec CollectLimitExec has been disabled, and is disabled by default because Collect Limit replacement can be slower on the GPU, if huge number of rows in a batch it could help by limiting the number of rows transferred from GPU to CPU. Set spark.rapids.sql.exec.CollectLimitExec to true if you wish to enable it
#   @Partitioning <SinglePartition$> could run on GPU
#   !Exec <ProjectExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; not all expressions can be replaced
#     @Expression <Alias> toprettystring(timestamp#0, Some(Asia/Kolkata)) AS toprettystring(timestamp)#6867 could run on GPU
#       !Expression <ToPrettyString> toprettystring(timestamp#0, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> timestamp#0 could run on GPU
#     @Expression <Alias> toprettystring(soil_moisture#1, Some(Asia/Kolkata)) AS toprettystring(soil_moisture)#6868 could run on GPU
#       !Expression <ToPrettyString> toprettystring(soil_moisture#1, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> soil_moisture#1 could run on GPU
#     @Expression <Alias> toprettystring(temperature#6, Some(Asia/Kolkata)) AS toprettystring(temperature)#6869 could run on GPU
#       !Expression <ToPrettyString> toprettystring(temperature#6, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> temperature#6 could run on GPU
#     @Expression <Alias> toprettystring(carbon_percent_interp#6771, Some(Asia/Kolkata)) AS toprettystring(carbon_percent_interp)#6870 could run on GPU
#       !Expression <ToPrettyString> toprettystring(carbon_percent_interp#6771, Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#     @Expression <Alias> toprettystring(UDF(features#6784), Some(Asia/Kolkata)) AS toprettystring(prediction)#6871 could run on GPU
#       !Expression <ToPrettyString> toprettystring(UDF(features#6784), Some(Asia/Kolkata)) cannot run on GPU because class org.apache.spark.sql.catalyst.expressions.ToPrettyString is not supported with timezone settings: (JVM: Asia/Kolkata, session: Asia/Kolkata). Set both of the timezones to UTC to enable class org.apache.spark.sql.catalyst.expressions.ToPrettyString support
#         !Expression <ScalaUDF> UDF(features#6784) cannot run on GPU because neither UDF implemented by class org.apache.spark.ml.PredictionModel$$Lambda/0x000070d7f942f9a8 provides a GPU implementation, nor the conf `spark.rapids.sql.rowBasedUDF.enabled` is enabled; param expression AttributeReference features#6784 (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#           !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#     !Exec <SampleExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#       !Exec <ProjectExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#         @Expression <AttributeReference> timestamp#0 could run on GPU
#         @Expression <AttributeReference> soil_moisture#1 could run on GPU
#         @Expression <AttributeReference> temperature#6 could run on GPU
#         @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#         !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         !Exec <SortExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]; not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#           @Expression <SortOrder> timestamp#0 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> timestamp#0 could run on GPU
#           @Expression <SortOrder> soil_moisture#1 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> soil_moisture#1 could run on GPU
#           @Expression <SortOrder> soil_water_content#2 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> soil_water_content#2 could run on GPU
#           @Expression <SortOrder> carbon_percent#3 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> carbon_percent#3 could run on GPU
#           @Expression <SortOrder> nitrogen_percent#4 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> nitrogen_percent#4 could run on GPU
#           @Expression <SortOrder> atmospheric_humidity#5 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> atmospheric_humidity#5 could run on GPU
#           @Expression <SortOrder> temperature#6 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> temperature#6 could run on GPU
#           @Expression <SortOrder> pH#7 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> pH#7 could run on GPU
#           @Expression <SortOrder> carbon_percent_interp#6771 ASC NULLS FIRST could run on GPU
#             @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#           !Expression <SortOrder> features#6784 ASC NULLS FIRST cannot run on GPU because input expression AttributeReference features#6784 (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression SortOrder features#6784 ASC NULLS FIRST produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#             !Expression <AttributeReference> features#6784 cannot run on GPU because expression AttributeReference features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#           !Exec <ProjectExec> cannot run on GPU because not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#6784]
#             @Expression <AttributeReference> timestamp#0 could run on GPU
#             @Expression <AttributeReference> soil_moisture#1 could run on GPU
#             @Expression <AttributeReference> soil_water_content#2 could run on GPU
#             @Expression <AttributeReference> carbon_percent#3 could run on GPU
#             @Expression <AttributeReference> nitrogen_percent#4 could run on GPU
#             @Expression <AttributeReference> atmospheric_humidity#5 could run on GPU
#             @Expression <AttributeReference> temperature#6 could run on GPU
#             @Expression <AttributeReference> pH#7 could run on GPU
#             @Expression <AttributeReference> carbon_percent_interp#6771 could run on GPU
#             !Expression <Alias> UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) AS features#6784 cannot run on GPU because expression Alias UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) AS features#6784 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#               !Expression <ScalaUDF> UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) cannot run on GPU because expression ScalaUDF UDF(struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; neither UDF implemented by class org.apache.spark.ml.feature.VectorAssembler$$Lambda/0x000070d7f92dd550 provides a GPU implementation, nor the conf `spark.rapids.sql.rowBasedUDF.enabled` is enabled
#                 @Expression <CreateNamedStruct> struct(soil_moisture_double_VectorAssembler_ccdf63b443b9, cast(soil_moisture#1 as double), temperature_double_VectorAssembler_ccdf63b443b9, cast(temperature#6 as double)) could run on GPU
#                   @Expression <Literal> soil_moisture_double_VectorAssembler_ccdf63b443b9 could run on GPU
#                   @Expression <Cast> cast(soil_moisture#1 as double) could run on GPU
#                     @Expression <AttributeReference> soil_moisture#1 could run on GPU
#                   @Expression <Literal> temperature_double_VectorAssembler_ccdf63b443b9 could run on GPU
#                   @Expression <Cast> cast(temperature#6 as double) could run on GPU
#                     @Expression <AttributeReference> temperature#6 could run on GPU
#
# [Stage 16:>                                                         (0 + 1) / 1]
# +---------+-------------+-----------+---------------------+------------------+
# |timestamp|soil_moisture|temperature|carbon_percent_interp|        prediction|
# +---------+-------------+-----------+---------------------+------------------+
# |     9486|        54.74|      28.95|    5.630000114440918|5.0103589803793245|
# |    12216|        29.81|      32.21|   0.5899999737739563| 5.012814446722369|
# |    13782|        76.87|       6.08|    2.130000114440918| 4.998854494363635|
# |    18501|        78.71|       12.9|    8.359999656677246| 5.001969135401481|
# |    22193|        54.67|       30.5|                  2.5| 5.011085137106117|
# +---------+-------------+-----------+---------------------+------------------+
# only showing top 5 rows

# %%
def plot_stats(stats, output_path):
    import pandas as pd
    import matplotlib.pyplot as plt
    # Create a DataFrame with the statistics.
    stats_pd = pd.DataFrame({
        "Stat": ["Mean", "Median", "StdDev", "Q1", "Q3"],
        "Carbon": [stats["carbon_mean"], stats["carbon_median"], stats["carbon_stddev"],
                   stats["carbon_quartiles"][0], stats["carbon_quartiles"][1]],
        "Nitrogen": [stats["nitrogen_mean"], stats["nitrogen_median"], stats["nitrogen_stddev"],
                     stats["nitrogen_quartiles"][0], stats["nitrogen_quartiles"][1]]
    })
    # Plot the DataFrame as a bar chart.
    ax = stats_pd.plot(x="Stat", y=["Carbon", "Nitrogen"], kind="bar", figsize=(10,6),
                         title="Soil Nutrient Statistics")
    ax.set_ylabel("Value")
    plt.tight_layout()
    plt.savefig(output_path)
    plt.close()

# Task 6: Visualization (using a separate thread).
print("Task 6: Generating Visualization")
plot_thread = Thread(target=plot_stats, args=(stats, "stats_plot.png"))
plot_thread.start()
plot_thread.join()
print("Bar chart saved as stats_plot.png")
# Out:
# Task 6: Generating Visualization
# Bar chart saved as stats_plot.png

# %%
# End Timing & Report Performance.
runtime = time.time() - start_time
print(f"Total Runtime: {runtime:.2f} seconds")
spark.stop()
# Out:
# Total Runtime: 1505.28 seconds
